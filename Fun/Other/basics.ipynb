# %% [markdown]
# # Imports

# %%
import pandas
import os

# %% [markdown]
# # Code

# %%
os.listdir()
filelocation = "files/supermarkets/"
filename = "supermarkets"

# %%
os.listdir("files/supermarkets")
# Out:
# ['supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %% [markdown]
# ## CSV

# %%
dfcsv = pandas.read_csv(filelocation + filename + ".csv")
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## JSON

# %%
dfjson = pandas.read_json(filelocation + filename + ".json")
dfjson
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## Excel NEW

# %%
dfxlsx = pandas.read_excel(filelocation + filename + ".xlsx", sheet_name=0)
dfxlsx
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %% [markdown]
# ## Excel OLD

# %%
dfxls = pandas.read_excel(filelocation + filename + ".xlrd", sheet_name=0)
dfxls

# %% [markdown]
# ## comma seperated text file

# %%
dftxtcom = pandas.read_csv(filelocation + filename + "-commas.txt")
dftxtcom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8256/2952014103.py in <module>
# ----> 1 df7 = dftxtcom
#       2 dftxtcom = pandas.read_csv(filelocation + filename + "-commas.txt")
#       3 dftxtcom
#
# NameError: name 'dftxtcom' is not defined

# %% [markdown]
# ## semicolons txt file

# %%
dftxtcol = pandas.read_csv(filelocation + filename + "-semi-colons.txt", sep = ";")
dftxtcol
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dftxtcol.columns = ["ID", "Adddress", "City", "Zip", "Country", "Name", "Employees"]
dftxtcol.index = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5', 'Row_6']
dftxtcol
# Out:
#        ID         Adddress           City               Zip Country  \
# Row_1   1     3666 21st St  San Francisco          CA 94114     USA
# Row_2   2   735 Dolores St  San Francisco          CA 94119     USA
# Row_3   3      332 Hill St  San Francisco  California 94114     USA
# Row_4   4     3995 23rd St  San Francisco          CA 94114     USA
# Row_5   5  1056 Sanchez St  San Francisco        California     USA
# Row_6   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                Name  Employees
# Row_1       Madeira          8
# Row_2   Bready Shop         15
# Row_3   Super River         25
# Row_4    Ben's Shop         10
# Row_5       Sanchez         12
# Row_6    Richvalley         20

# %%
dftxtcol.set_index("ID", inplace = True,drop = False)
dftxtcol
# Out:
#     ID         Adddress           City               Zip Country  \
# ID
# 1    1     3666 21st St  San Francisco          CA 94114     USA
# 2    2   735 Dolores St  San Francisco          CA 94119     USA
# 3    3      332 Hill St  San Francisco  California 94114     USA
# 4    4     3995 23rd St  San Francisco          CA 94114     USA
# 5    5  1056 Sanchez St  San Francisco        California     USA
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#             Name  Employees
# ID
# 1        Madeira          8
# 2    Bready Shop         15
# 3    Super River         25
# 4     Ben's Shop         10
# 5        Sanchez         12
# 6     Richvalley         20

# %%
dftxtcol.set_index("Adddress",inplace=True,drop=False)
df7 = dftxtcol

# %%
test = list(df7.loc["332 Hill St":,"Country"])
print(test)
test2 = [x for x in test if x == "USA"]
print(test2)
# Out:
# ['USA', 'USA', 'USA', 'USA']
# ['USA', 'USA', 'USA', 'USA']

# %%
df7.iloc[1:,1:3]
# Out:
#                         Adddress           City
# Adddress
# 735 Dolores St    735 Dolores St  San Francisco
# 332 Hill St          332 Hill St  San Francisco
# 3995 23rd St        3995 23rd St  San Francisco
# 1056 Sanchez St  1056 Sanchez St  San Francisco
# 551 Alvarado St  551 Alvarado St  San Francisco

# %%
df7.drop(df7.columns[3:],1)
# Out:
# C:\Users\kevin\AppData\Local\Temp/ipykernel_8256/2936233690.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop(df7.columns[3:],1)
#                  ID         Adddress           City
# Adddress
# 3666 21st St      1     3666 21st St  San Francisco
# 735 Dolores St    2   735 Dolores St  San Francisco
# 332 Hill St       3      332 Hill St  San Francisco
# 3995 23rd St      4     3995 23rd St  San Francisco
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco
# 551 Alvarado St   6  551 Alvarado St  San Francisco

# %%
df7.columns[0:]
# Out:
# Index(['ID', 'Adddress', 'City', 'Zip', 'Country', 'Name', 'Employees',
#        'Continent'],
#       dtype='object')

# %%
len(df7.index)
# Out:
# 6

# %%
df7["Continent"] = df7.shape[0] * ["North America"]
df7
# Out:
#                  ID         Adddress           City               Zip Country  \
# Adddress
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                          Name  Employees      Continent
# Adddress
# 3666 21st St          Madeira          8  North America
# 735 Dolores St    Bready Shop         15  North America
# 332 Hill St       Super River         25  North America
# 3995 23rd St       Ben's Shop         10  North America
# 1056 Sanchez St       Sanchez         12  North America
# 551 Alvarado St    Richvalley         20  North America

# %%
df7_t=df7.T
df7_t
# Out:
# Adddress    3666 21st St  735 Dolores St       332 Hill St   3995 23rd St  \
# ID                     1               2                 3              4
# Adddress    3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Zip             CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  North America   North America     North America  North America
#
# Adddress   1056 Sanchez St  551 Alvarado St
# ID                       5                6
# Adddress   1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# Zip             California         CA 94114
# Country                USA              USA
# ...

# %%
df7_t["My Address"] = ["My City","Address","my Country",10,7,"My Shop", "my State", "My Continent"]
df7_t
# Out:
# Adddress    3666 21st St  735 Dolores St       332 Hill St   3995 23rd St  \
# ID                     1               2                 3              4
# Adddress    3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Zip             CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  North America   North America     North America  North America
#
# Adddress   1056 Sanchez St  551 Alvarado St    My Address
# ID                       5                6       My City
# Adddress   1056 Sanchez St  551 Alvarado St       Address
# City         San Francisco    San Francisco    my Country
# Zip             California         CA 94114            10
# ...

# %%
df7 = df7_t.T
df7
# Out:
#                       ID         Adddress           City               Zip  \
# Adddress
# 3666 21st St           1     3666 21st St  San Francisco          CA 94114
# 735 Dolores St         2   735 Dolores St  San Francisco          CA 94119
# 332 Hill St            3      332 Hill St  San Francisco  California 94114
# 3995 23rd St           4     3995 23rd St  San Francisco          CA 94114
# 1056 Sanchez St        5  1056 Sanchez St  San Francisco        California
# 551 Alvarado St        6  551 Alvarado St  San Francisco          CA 94114
# My Address       My City          Address     my Country                10
#
#                 Country          Name Employees      Continent
# Adddress
# 3666 21st St        USA       Madeira         8  North America
# 735 Dolores St      USA   Bready Shop        15  North America
# 332 Hill St         USA   Super River        25  North America
# 3995 23rd St        USA    Ben's Shop        10  North America
# ...

# %%
df7.shape[0]
test = df7.T
test.shape[0]
df7.set_index("Adddress",drop = False, inplace = True)
df7
# Out:
#                       ID         Adddress           City               Zip  \
# Adddress
# 3666 21st St           1     3666 21st St  San Francisco          CA 94114
# 735 Dolores St         2   735 Dolores St  San Francisco          CA 94119
# 332 Hill St            3      332 Hill St  San Francisco  California 94114
# 3995 23rd St           4     3995 23rd St  San Francisco          CA 94114
# 1056 Sanchez St        5  1056 Sanchez St  San Francisco        California
# 551 Alvarado St        6  551 Alvarado St  San Francisco          CA 94114
# Address          My City          Address     my Country                10
#
#                 Country          Name Employees      Continent
# Adddress
# 3666 21st St        USA       Madeira         8  North America
# 735 Dolores St      USA   Bready Shop        15  North America
# 332 Hill St         USA   Super River        25  North America
# 3995 23rd St        USA    Ben's Shop        10  North America
# ...

# %%
type(df7)
# Out:
# pandas.core.frame.DataFrame

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
n = nom.geocode("3995 23rd St, San Francisco,  California 94114,")
n
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
import pandas
df = pandas.read_csv("files/supermarkets/supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"] + ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0].latitude
type(df.Coordinates[0])
# Out:
# geopy.location.Location

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)

# %%
df.T
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
