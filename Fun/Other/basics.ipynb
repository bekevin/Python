# %% [markdown]
# # Imports

# %%
import pandas
import os

# %% [markdown]
# # Code

# %%
os.listdir()
filelocation = "files/supermarkets/"
filename = "supermarkets"

# %%
os.listdir("files/supermarkets")
# Out:
# ['supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %% [markdown]
# ## CSV

# %%
dfcsv = pandas.read_csv(filelocation + filename + ".csv")
dfcsv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## JSON

# %%
dfjson = pandas.read_json(filelocation + filename + ".json")
dfjson
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## Excel NEW

# %%
dfxlsx = pandas.read_excel(filelocation + filename + ".xlsx", sheet_name=0)
dfxlsx
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %% [markdown]
# ## Excel OLD

# %%
dfxls = pandas.read_excel(filelocation + filename + ".xlrd", sheet_name=0)
dfxls

# %% [markdown]
# ## comma seperated text file

# %%
dftxtcom = pandas.read_csv(filelocation + filename + "-commas.txt")
dftxtcom
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## semicolons txt file

# %%
dftxtcol = pandas.read_csv(filelocation + filename + "-semi-colons.txt", sep = ";")
dftxtcol
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dftxtcol.columns = ["ID", "Adddress", "City", "Zip", "Country", "Name", "Employees"]
dftxtcol.index = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5', 'Row_6']
dftxtcol
# Out:
#        ID         Adddress           City               Zip Country  \
# Row_1   1     3666 21st St  San Francisco          CA 94114     USA
# Row_2   2   735 Dolores St  San Francisco          CA 94119     USA
# Row_3   3      332 Hill St  San Francisco  California 94114     USA
# Row_4   4     3995 23rd St  San Francisco          CA 94114     USA
# Row_5   5  1056 Sanchez St  San Francisco        California     USA
# Row_6   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                Name  Employees
# Row_1       Madeira          8
# Row_2   Bready Shop         15
# Row_3   Super River         25
# Row_4    Ben's Shop         10
# Row_5       Sanchez         12
# Row_6    Richvalley         20

# %%
dftxtcol.set_index("ID", inplace=True)
dftxtcol
# Out:
#            Adddress           City               Zip Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
dftxtcol.set_index("Adddress",inplace=True,drop=False)
dftxtcol
# Out:
#                         Adddress           City               Zip Country  \
# Adddress
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                          Name  Employees
# Adddress
# 3666 21st St          Madeira          8
# 735 Dolores St    Bready Shop         15
# 332 Hill St       Super River         25
# 3995 23rd St       Ben's Shop         10
# 1056 Sanchez St       Sanchez         12
# 551 Alvarado St    Richvalley         20

# %%
pandas.DataFrame.set_index?
# Out:
# Signature:
# pandas.DataFrame.set_index(
#     self,
#     keys,
#     drop: 'bool' = True,
#     append: 'bool' = False,
#     inplace: 'bool' = False,
#     verify_integrity: 'bool' = False,
# )
# Docstring:
# Set the DataFrame index using existing columns.
#
# Set the DataFrame index (row labels) using one or more existing
# columns or arrays (of the correct length). The index can replace the
# existing index or expand on it.
#
# Parameters
# ----------
# keys : label or array-like or list of labels/arrays
#     This parameter can be either a single column key, a single array of
#     the same length as the calling DataFrame, or a list containing an
#     arbitrary combination of column keys and arrays. Here, "array"
#     encompasses :class:`Series`, :class:`Index`, ``np.ndarray``, and
#     instances of :class:`~collections.abc.Iterator`.
# drop : bool, default True
#     Delete columns to be used as the new index.
# append : bool, default False
# ...
